# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from datetime import datetime
import time
import datetime

import eikon as ek
#API Key Lionel: d505f265d9bd4c0cb7df44481ece31a0ad8d1974
#API Key Raphi: f5a341b614d945b9b93a71fe53348ba119d11e99
ek.set_app_key('f5a341b614d945b9b93a71fe53348ba119d11e99')

# %% [markdown]
# # Futures

# %%
BQL_Futures = pd.read_excel('Excel_Data_Bloomberg_BQL.xlsx',sheet_name='Futures_Fix', index_col='DATES')
BQL_Futures.head()
# Out:
#                      CL1 Comdty  C 1 Comdty  GC1 Comdty  LC1 Comdty  \
# DATES
# 2011-12-30 00:00:00    98.82999      646.50      1566.8      122.90
# 2012-01-31 00:00:00    98.48000      639.00      1737.8      124.85
# 2012-02-29 00:00:00   107.07000      656.50      1711.3      127.65
# 2012-03-30 00:00:00   103.02000      644.00      1669.3      120.45
# 2012-04-30 00:00:00   104.87000      660.25      1664.2      118.75
#
#                      FN1 Comdty  NG1 Comdty  JO1 Comdty  PA1 Comdty  \
# DATES
# 2011-12-30 00:00:00       54.31       2.989      169.00      656.15
# 2012-01-31 00:00:00       56.25       2.503      210.00      686.35
# 2012-02-29 00:00:00       59.38       2.616      190.55      706.65
# 2012-03-30 00:00:00       61.50       2.126      164.50      654.10
# 2012-04-30 00:00:00       57.87       2.285      140.85      682.35
#
#                      PL1 Comdty  SI1 Comdty  W 1 Comdty
# DATES
# 2011-12-30 00:00:00      1399.7      27.915      652.75
# ...

# %%
BQL_Futures.describe()
# Out:
#        CL1 Comdty  C 1 Comdty   GC1 Comdty  LC1 Comdty  FN1 Comdty  \
# count  121.000000  121.000000   121.000000  121.000000  121.000000
# mean    65.972727  450.522727  1424.242975  124.804132   54.198926
# std     22.254328  133.158282   241.144257   16.507157   33.657163
# min     18.840000  301.500000  1060.200000   90.000000    9.630000
# 25%     48.520000  358.750000  1242.300000  113.450000   39.500000
# 50%     60.140000  384.500000  1318.500000  122.075000   49.810000
# 75%     88.060000  534.000000  1660.600000  132.925000   60.680000
# max    107.650000  806.500000  1970.500000  169.500000  251.180000
#
#        NG1 Comdty  JO1 Comdty   PA1 Comdty   PL1 Comdty  SI1 Comdty  \
# count  121.000000  121.000000   121.000000   121.000000  121.000000
# mean     3.064397  135.726860  1149.404959  1113.209917   20.139744
# std      0.807724   25.664986   647.483109   260.859272    5.438254
# min      1.640000   94.800000   495.600000   724.400000   13.803000
# ...

# %% [markdown]
# # Makros

# %%
BQL_Makros = pd.read_excel('Excel_Data_Bloomberg_BQL.xlsx',sheet_name='Makro_Fix', index_col='DATES')
BQL_Makros.head()
# Out:
#             SZCPIYOY Index  SZUEUEA Index  SZPUI Index  CNCPIYOY Index  \
# DATES
# 2011-12-31            -0.7        2.78311         49.3             4.1
# 2012-01-31            -0.8        2.99854         47.9             4.5
# 2012-02-29            -0.9        2.81006         47.9             3.2
# 2012-03-31            -1.0        2.80185         50.5             3.6
# 2012-04-30            -1.0        2.84700         46.7             3.4
#
#             CPMINDX Index  UMRTEMU Index  ECCPEMUY Index  RUCPIYOY Index  \
# DATES
# 2011-12-31           50.3           10.8             2.8        6.100000
# 2012-01-31           50.5           10.9             2.7        4.143126
# 2012-02-29           51.0           11.1             2.7        3.738318
# 2012-03-31           53.1           11.2             2.7        3.714020
# 2012-04-30           53.3           11.3             2.6        3.607771
#
#             RUUER Index  CPI CHNG Index  NAPMPMI Index  USURTOT Index
# DATES
# ...

# %%
BQL_Makros.describe()
# Out:
#        SZCPIYOY Index  SZUEUEA Index  SZPUI Index  CNCPIYOY Index  \
# count      121.000000     121.000000   121.000000      121.000000
# mean        -0.089256       2.974412    54.162810        2.087268
# std          0.728560       0.347253     6.567802        0.993951
# min         -1.400000       2.253810    41.200000       -0.500000
# 25%         -0.600000       2.801850    49.200000        1.500000
# 50%         -0.100000       3.054180    53.100000        2.000000
# 75%          0.600000       3.232560    57.900000        2.500000
# max          1.500000       3.477510    70.000000        5.384570
#
#        CPMINDX Index  UMRTEMU Index  ECCPEMUY Index  RUCPIYOY Index  \
# count     121.000000     121.000000      121.000000      121.000000
# mean       50.510744       9.717355        1.217355        6.331513
# std         1.590430       1.719577        1.041448        3.603266
# min        35.700000       7.000000       -0.600000        2.162170
# ...
